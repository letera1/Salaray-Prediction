# %% [markdown]
# # 📊 Ethiopian Tech Salary Data - Comprehensive Exploration & Analysis
#
# ## Overview
# This notebook provides an in-depth exploration and analysis of Ethiopian technology sector salary data. We'll examine patterns, distributions, correlations, and insights that drive compensation in Ethiopia's growing tech industry.
#
# ### Objectives:
# - 🔍 **Exploratory Data Analysis**: Understand data structure and quality
# - 📈 **Statistical Analysis**: Identify key patterns and distributions
# - 🎯 **Feature Analysis**: Examine relationships between variables
# - 🌍 **Geographic Insights**: Analyze location-based salary variations
# - 🎓 **Education Impact**: Study education level effects on compensation
# - 💼 **Department Analysis**: Compare salaries across tech departments
#
# ---

# %% [markdown]
# ## 📚 Import Libraries and Setup
#
# We'll use a comprehensive set of libraries for data analysis, visualization, and statistical testing.

# %%
# Core data manipulation and analysis
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import pearsonr, spearmanr, chi2_contingency
import warnings
warnings.filterwarnings('ignore')

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff

# Statistical analysis
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Display and formatting
from IPython.display import display, HTML, Markdown
import datetime

# Configuration
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# Plotly configuration
import plotly.io as pio
pio.templates.default = "plotly_white"

print("📚 All libraries imported successfully!")
print(f"🕒 Analysis started at: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
