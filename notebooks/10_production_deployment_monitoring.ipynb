# %% [markdown]
# # 🚀 Production Deployment & Model Monitoring
#
# ## Overview
# This notebook covers the complete production deployment pipeline for Ethiopian salary prediction models, including model serving, monitoring, and maintenance strategies.
#
# ### Production Components:
# - 📦 **Model Packaging**: Serialization and containerization
# - 🌐 **API Development**: RESTful service creation
# - 📊 **Performance Monitoring**: Real-time metrics tracking
# - 🔄 **Model Versioning**: Version control and rollback
# - 📈 **Drift Detection**: Data and concept drift monitoring
# - 🔧 **Automated Retraining**: Continuous model improvement
#
# ---

# %%
# Import production deployment libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Model serialization and deployment
import joblib
import pickle
import json
import yaml
from datetime import datetime, timedelta
import time
import os
import logging

# API development
try:
    from flask import Flask, request, jsonify
    from flask_restx import Api, Resource, fields
    FLASK_AVAILABLE = True
    print("✅ Flask available for API development")
except ImportError:
    FLASK_AVAILABLE = False
    print("⚠️ Flask not available. Install with: pip install flask flask-restx")

try:
    from fastapi import FastAPI, HTTPException
    from pydantic import BaseModel
    import uvicorn
    FASTAPI_AVAILABLE = True
    print("✅ FastAPI available for high-performance APIs")
except ImportError:
    FASTAPI_AVAILABLE = False
    print("⚠️ FastAPI not available. Install with: pip install fastapi uvicorn")

# Model monitoring
try:
    import mlflow
    import mlflow.sklearn
    MLFLOW_AVAILABLE = True
    print("✅ MLflow available for model tracking")
except ImportError:
    MLFLOW_AVAILABLE = False
    print("⚠️ MLflow not available. Install with: pip install mlflow")

# Drift detection
try:
    from evidently import ColumnMapping
    from evidently.report import Report
    from evidently.metric_preset import DataDriftPreset, TargetDriftPreset
    EVIDENTLY_AVAILABLE = True
    print("✅ Evidently available for drift detection")
except ImportError:
    EVIDENTLY_AVAILABLE = False
    print("⚠️ Evidently not available. Install with: pip install evidently")

# Scikit-learn for model operations
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Utilities
from IPython.display import display, HTML
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

print("\n🚀 Production Deployment Setup Complete!")
print(f"🌐 Flask: {FLASK_AVAILABLE}")
print(f"⚡ FastAPI: {FASTAPI_AVAILABLE}")
print(f"📊 MLflow: {MLFLOW_AVAILABLE}")
print(f"🔍 Evidently: {EVIDENTLY_AVAILABLE}")
print("🎯 Ready for Production Deployment!")
